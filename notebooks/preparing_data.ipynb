# %% [markdown]
# # 0. Load data

# %%
import pandas as pd
import json
import os

# %% [markdown]
# ## 1.1. course.json

# %%
import pandas as pd
import json
import os

path = r'C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw'
 
data_name = r'course_translated.json'
data_list = []

data_path = os.path.join(path, data_name)
print(data_path)

with open(data_path, "r", encoding="utf-8") as file:
    data_list = json.load(file)

course_df = pd.DataFrame(data_list)
course_df.head()
# Out:
# C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw\course_translated.json
#          id                                         name_trans  \
# 0  C_584313                 introduction to "zi zhi tong jian"
# 1  C_584329  calculus - limit theory and functions of one v...
# 2  C_584381                                    photojournalism
# 3  C_597208                 data mining: theory and algorithms
# 4  C_597225                                university computer
#
#                                                field prerequisites_trans  \
# 0         [history, chinese language and literature]
# 1  [applied economics, math, physics, theoretical...
# 2                [art, journalism and communication]
# 3                  [computer science and technology]
# 4                                                 []
#
#                                          about_trans  \
# ...

# %% [markdown]
# ## 1.2. concept.json

# %%
data_name = r'concept_translated.json'
data_list = []

data_path = os.path.join(path, data_name)
print(data_path)

with open(data_path, 'r') as file:
    for line in file:
        data_list.append(json.loads(line))

concept_df = pd.DataFrame(data_list)
concept_df.head()
# Out:
# C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw\concept_translated.json
#                    id                  name  \
# 0       K_神经部_组织学与胚胎学        Nervous system
# 1  K_促甲状腺激素细胞_组织学与胚胎学             TSH cells
# 2      K_嗜色细胞_组织学与胚胎学    Chromophilic cells
# 3    K_生长激素细胞_组织学与胚胎学  Growth hormone cells
# 4       K_褐铁矿_材料科学与工程              Limonite
#
#                                              context
# 0                                                 []
# 1  ['The pituitary gland consists of two parts: t...
# 2                                                 []
# 3  ['Answer: B\n13. Adenohypophysis eosinophils c...
# 4  ['\nLimonite is a common iron ore, often forme...

# %% [markdown]
# ## 1.3. course-field.json

# %%
data_name = r'course-field_translated.json'
data_list = []

data_path = os.path.join(path, data_name)
print(data_path)

with open(data_path, 'r', encoding='utf-8') as file:
    for line in file:
        data_list.append(json.loads(line))

course_field_df = pd.DataFrame(data_list)
course_field_df.head()
# Out:
# C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw\course-field_translated.json
#    course_id                                  course_name  \
# 0     584313           Introduction to "Zi Zhi Tong Jian"
# 1     681932         "Learning by doing" Java programming
# 2     674962   The spatial art of "Dream of Red Mansions"
# 3     682709  Introduction to the Critique of Pure Reason
# 4     682635               Introduction to "Tongwancheng"
#
#                                         field
# 0  [Chinese language and literature, History]
# 1           [Computer Science and Technology]
# 2           [Chinese language and literature]
# 3                                [philosophy]
# 4                                   [History]

# %% [markdown]
# ## 1.4. school.json

# %%
data_name = r'school_translated.json'
data_list = []

data_path = os.path.join(path, data_name)
print(data_path)

with open(data_path, 'r', encoding='utf-8') as file:
    school_data = json.load(file)

school_df = pd.DataFrame(school_data)
school_df.head()
# Out:
# C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw\school_translated.json
#     id  name              name_en  sign  \
# 0  S_1  清华大学  Tsinghua University   thu
# 1  S_2  北京大学    Peking University   PKU
# 2  S_3  武汉大学     Wuhan University   whu
# 3  S_4  苏州大学   Soochow University  suda
# 4  S_5  四川大学   Sichuan University   scu
#
#                                                about  \
# 0  "Tsinghua" for short, is directly under the Mi...
# 1  Peking University, referred to as "Peking Univ...
# 2  Wuhan University (Wuhan University), referred ...
# 3  Soochow University, located in the historical ...
# 4  Sichuan University, referred to as "Sichuan Un...
#
#                                                motto
# 0  Constantly strive for self-improvement and be ...
# 1  erudition, inquiry, careful consideration, dis...
# 2  Self-improvement, Hongyi, Seeking truth, Expan...
# ...

# %% [markdown]
# ## 1.5. teacher.json

# %%
data_name = r'teacher.json'
data_list = []

data_path = os.path.join(path, data_name)
print(data_path)

with open(data_path, 'r') as file:
    for line in file:
        data_list.append(json.loads(line))

teacher_df = pd.DataFrame(data_list)
teacher_df.head()
# Out:
# C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw\teacher.json
#     id name        name_en                                              about  \
# 0  T_1  刘燕妮      Yanni Liu  Graduated from the Philosophy Department of Pe...
# 1  T_2   陈怡        Yi Chen  Born in Chongqing in 1945, he graduated from H...
# 2  T_3   程钢     Gang Cheng  Cheng Gang is the course leader of "Introducti...
# 3  T_4  谢维和     xie wei he  Xie Weihe, PhD, professor, doctoral supervisor...
# 4  T_5  史静寰  Jing-huan Shi  Shi Jinghuan, female, professor and doctoral s...
#
#              job_title             org_name
# 0             lecturer  Tsinghua University
# 1            professor  Tsinghua University
# 2  Associate Professor  Tsinghua University
# 3            professor  Tsinghua University
# 4            professor  Tsinghua University

# %% [markdown]
# ## 1.6. user.json

# %%
data_name = r'user_translated.json'
data_list = []

data_path = os.path.join(path, data_name)
print(data_path)

with open(data_path, 'r') as file:
    for line in file:
        data_list.append(json.loads(line))

user_df = pd.DataFrame(data_list)
# Out:
# C:\Users\ADMIN\Desktop\HK5\Khai phá dữ liệu doanh nghiệp\2.1) code preprocessed-20241125T052257Z-001\Final_dataset\raw\user_translated.json

# %% [markdown]
# # 1. Translating

# %% [markdown]
# # 2. Khám phá dữ liệu

# %% [markdown]
# ## 2.1. course.json

# %% [markdown]
# ### 2.1.1. Thống kê mô tả

# %%
course_df.describe(include='all')
# Out:
#               id      name_trans field prerequisites_trans about_trans  \
# count       3781            3781  3781                3781        3781
# unique      3781            3134   147                 773        3190
# top     C_584313  linear algebra    []
# freq           1               9  3234                2580          89
#
#                                                  resource
# count                                                3781
# unique                                               3781
# top     [{'titles': ['第一课 导论与三家分晋', '导论', '导论'], 'reso...
# freq                                                    1

# %%
course_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3781 entries, 0 to 3780
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3781 non-null   object
#  1   name_trans           3781 non-null   object
#  2   field                3781 non-null   object
#  3   prerequisites_trans  3781 non-null   object
#  4   about_trans          3781 non-null   object
#  5   resource             3781 non-null   object
# dtypes: object(6)
# memory usage: 177.4+ KB

# %%
total_courses = course_df.shape[0]
print(f"1) Total number of courses: {total_courses}")

print('-----------------')

field_counts = course_df['field'].explode().value_counts()
print("2) Number of courses by field:")
print(field_counts)
# Out:
# 1) Total number of courses: 3781
# -----------------
# 2) Number of courses by field:
# field
# computer science and technology       63
# art                                   35
# foreign languages ​​and literature    34
# math                                  21
# history                               20
#                                       ..
# marine science                         1
# ship and marine engineering            1
# army command science                   1
# metallurgical engineering              1
# basic chinese medicine                 1
# Name: count, Length: 81, dtype: int64

# %%
### create new columns for description length
course_df['about_length'] = course_df['about_trans'].apply(len)
course_df['name_length'] = course_df['name_trans'].apply(len)
course_df['resource_length'] = course_df['resource'].apply(len)

course_df[['about_length', 'name_length', 'resource_length']].describe()
# Out:
#        about_length  name_length  resource_length
# count   3781.000000  3781.000000      3781.000000
# mean     393.445120    36.942343        71.685533
# std      267.904934    21.575065        74.802345
# min        0.000000     2.000000         1.000000
# 25%      217.000000    22.000000        38.000000
# 50%      361.000000    32.000000        59.000000
# 75%      509.000000    46.000000        88.000000
# max     2293.000000   193.000000      2728.000000

# %%
course_df['resource'][0][0]
# Out:
# {'titles': ['第一课 导论与三家分晋', '导论', '导论'],
#  'resource_id': 'V_849',
#  'chapter': '1.1.1'}

# %%
# Tạo một tập hợp để lưu các video ID duy nhất (bắt đầu bằng 'V_')
unique_video_ids = set()

# Lặp qua từng hàng trong cột 'resource'
for resources in course_df['resource']:
  for resource in resources:
    if resource['resource_id'].startswith('V_'):
      unique_video_ids.add(resource['resource_id'])
print(f"Total number of unique video IDs: {len(unique_video_ids)}")
print(f"First 10 unique video IDS: {list(unique_video_ids)[:10]}")
# Out:
# Total number of unique video IDs: 203718
# First 10 unique video IDS: ['V_6168243', 'V_883305', 'V_103051', 'V_60470', 'V_151461', 'V_35906', 'V_1366750', 'V_49291', 'V_3590422', 'V_380613']

# %%
import pandas as pd

ccid_df = pd.read_csv('https://lfs.aminer.cn/misc/moocdata/data/mooccube2/relations/video_id-ccid.txt', delimiter='\t', header=None)

# %%
ccid_df.rename(columns={0: 'video_id', 1: 'ccid'}, inplace=True)
ccid_df.head()
# Out:
#    video_id                              ccid
# 0  V_234845  0000363DB5B6E0869C33DC5901307461
# 1  V_234876  0000363DB5B6E0869C33DC5901307461
# 2  V_234907  0000363DB5B6E0869C33DC5901307461
# 3  V_293392  0000363DB5B6E0869C33DC5901307461
# 4  V_293445  0000363DB5B6E0869C33DC5901307461

# %%
videoID = ccid_df['video_id'].unique()

valid_videoID = set(videoID)

non_existent_ids = unique_video_ids - valid_videoID

# Hiển thị kết quả
print(f"Tổng số lượng các video ID không tồn tại: {len(non_existent_ids)}")
print(f"Các video ID không tồn tại: {non_existent_ids}")
# Out:
# Tổng số lượng các video ID không tồn tại: 2397
# ...

# %% [markdown]
# ### 2.2.2. Trực quan hóa dữ liệu

# %%
import matplotlib.pyplot as plt
import pandas as pd
## count number of course in each field
field_counts = course_df.explode('field')['field'].value_counts()
field_counts = field_counts.sort_values(ascending=True)


field_counts.plot(kind='barh', figsize=(12, 12))
plt.title('Number of Courses by Field')
plt.xlabel('Number of Courses')
plt.ylabel('Field')
plt.tight_layout()  # Adjust layout to prevent cut off
plt.show()

# %%
# select top N
N = 9
top_15_fields = field_counts.nlargest(N)
other_fields_count = field_counts[N:].sum()

top_15_fields['Other'] = other_fields_count

# Plot
plt.figure(figsize=(8, 8))
top_15_fields.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title(f'Number of Courses by Field (Top {N})')
plt.ylabel('') 
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Count number of fields in each course
course_df['field_count'] = course_df['field'].apply(len)
course_count_by_field = course_df.groupby('field_count').size()
bars = course_count_by_field.plot(kind='bar')

# Add numbers on each bar
for bar in bars.patches:
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        bar.get_height(),
        int(bar.get_height()),
        ha='center',
        va='bottom'
    )

plt.title('Number of Fields in each courses')
plt.xlabel('Number of Fields')
plt.ylabel('Number of Courses')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
course_df['has_prerequisites'] = course_df['prerequisites_trans'].apply(lambda x: False if x is None or x == '' else True)

# Create the count plot
plt.figure(figsize=(8, 6))
sns.countplot(x='has_prerequisites', data=course_df)
plt.title('Distribution of Courses with and Without Prerequisites')
plt.xlabel('Has Prerequisites')
plt.ylabel('Number of Courses')
plt.show()

# %%
# kiểm tra outliners
sns.boxplot(x=course_df['about_length'])
# Out:
# <Axes: xlabel='about_length'>

# %% [markdown]
# ## 2.2. concept.json

# %% [markdown]
# ### 2.2.1. Thống kê mô tả

# %%
# Thống kê cơ bản
concept_df.describe()
# Out:
#                    id    name context
# count          637572  637572  637572
# unique         637572  489886  101566
# top     K_神经部_组织学与胚胎学    Goby      []
# freq                1      84  313561

# %% [markdown]
# ## 2.3. course-field.json

# %% [markdown]
# ### 2.3.1 Thống kê mô tả

# %%
# 1. Số lượng khóa học
num_courses = course_field_df['course_id'].nunique()
print(f"Số lượng khóa học: {num_courses}")

# 2. Số lượng các lĩnh vực khác nhau
unique_fields = set(field for fields_list in course_field_df['field'] for field in fields_list)
num_unique_fields = len(unique_fields)
print(f"Số lượng các lĩnh vực khác nhau: {num_unique_fields}")
# Out:
# Số lượng khóa học: 632
# Số lượng các lĩnh vực khác nhau: 82

# %%
# 3. Phân bố số lượng khóa học theo từng lĩnh vực
field_distribution = course_field_df.explode('field')['field'].value_counts()
print("\nPhân bố số lượng khóa học theo từng lĩnh vực:")
print(field_distribution)
# Out:
# Phân bố số lượng khóa học theo từng lĩnh vực:
# field
# Computer Science and Technology                      75
# foreign languages ​​and literature                   43
# Art                                                  38
# Chinese language and literature                      26
# Management Science and Engineering                   25
#                                                      ..
# Battle Science                                        1
# Military Logistics and Military Equipment Science     1
# Weapons Science and Technology                        1
# Army Command Science                                  1
# Mining Engineering                                    1
# Name: count, Length: 82, dtype: int64

# %%
# 4. Phân bố độ dài tên khóa học (số ký tự)
course_name_length = course_field_df['course_name'].apply(len)
print("\nThống kê độ dài tên khóa học:")
print(course_name_length.describe())
# Out:
# Thống kê độ dài tên khóa học:
# count    632.000000
# mean      33.507911
# std       16.882082
# min        2.000000
# 25%       21.000000
# 50%       31.000000
# 75%       41.000000
# max      130.000000
# Name: course_name, dtype: float64

# %% [markdown]
# ### 2.3.2. Trực quan hóa dữ liệu

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Explode the 'field' column to get individual field entries and count occurrences
field_distribution = course_field_df.explode('field')['field'].value_counts()

# Get the top 10 fields and calculate the sum of "Others"
top_10_fields = field_distribution.nlargest(10)
others_count = field_distribution[10:].sum()

# Prepare data for the pie chart
labels = top_10_fields.index.tolist() + ['Others']
sizes = top_10_fields.values.tolist() + [others_count]

# Create the circle (pie) chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('viridis', len(labels)))
plt.title('Phân bố số lượng khóa học theo từng lĩnh vực (Top 10 + Others)', fontsize=16)
plt.show()

# %% [markdown]
# ## 2.4. school.json

# %% [markdown]
# ### 2.4.1 Thống kê mô tả

# %%
school_df.describe(include='all')
# Out:
#          id  name                          name_en  sign  \
# count   428   428                              428   428
# unique  428   421                              423   420
# top     S_1  长安大学  Dalian University of Technology  hzic
# freq      1     2                                2     2
#
#                                                     about motto
# count                                                 428   428
# unique                                                420   138
# top     Hebei Normal University Of Science & Technolog...
# freq                                                    2   282

# %%
pd.DataFrame(school_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       428 non-null    object
#  1   name     428 non-null    object
#  2   name_en  428 non-null    object
#  3   sign     428 non-null    object
#  4   about    428 non-null    object
#  5   motto    428 non-null    object
# dtypes: object(6)
# memory usage: 20.2+ KB
# Empty DataFrame
# Columns: []
# Index: []

# %%
school_df['about_length'] = school_df['about'].apply(len)
school_df['motto_length'] = school_df['motto'].apply(len)
# Display summary 
school_df[['about_length', 'motto_length']].describe()
# Out:
#        about_length  motto_length
# count    428.000000    428.000000
# mean    2023.530374     16.955607
# std      737.761007     26.937787
# min      134.000000      0.000000
# 25%     1552.750000      0.000000
# 50%     2157.000000      0.000000
# 75%     2647.750000     42.000000
# max     3126.000000    134.000000

# %% [markdown]
# ### 2.5.2. Trực quan hóa dữ liệu

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot about_length, bin = 10 is the number of bars, kde = true is for the line
plt.figure(figsize=(10, 6))
sns.histplot(school_df['about_length'], bins=10, kde=True)
plt.title('About Length')
plt.xlabel('')
plt.ylabel('Frequency')
plt.show()

# Plot motto_length
plt.figure(figsize=(10, 6))
sns.histplot(school_df['motto_length'], bins=10, kde=True)
plt.title('Motto Length')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 2.5. teacher.json

# %% [markdown]
# ### 2.5.1. Thống kê mô tả

# %%
teacher_df.describe()
# Out:
#            id   name name_en     about            job_title  \
# count   17018  17018   17018     13893                14768
# unique  17018  13967   11061     12536                 1323
# top       T_1    顾礼平          slightly  Associate Professor
# freq        1     20    4142       626                 4305
#
#                    org_name
# count                 17018
# unique                  998
# top     Tsinghua University
# freq                   1140

# %%
teacher_df.dtypes
# Out:
# id           object
# name         object
# name_en      object
# about        object
# job_title    object
# org_name     object
# dtype: object

# %%
teacher_df.isnull().sum()
# Out:
# id              0
# name            0
# name_en         0
# about        3125
# job_title    2250
# org_name        0
# dtype: int64

# %% [markdown]
# ### 2.5.2. Trực quan hóa dữ liệu

# %%
job_counts = teacher_df['job_title'].value_counts().dropna()


plt.figure(figsize=(10, 6))
job_counts[:10].plot(kind='bar', color='skyblue')
plt.title('Top 10 Job Title Distribution')
plt.xlabel('Job Title')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.show()

# %%
job_counts = teacher_df['org_name'].value_counts().dropna()

plt.figure(figsize=(10, 6))
job_counts[:10].plot(kind='bar', color='skyblue')
plt.title('Top 10 Orgs')
plt.xlabel('Org name')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')

plt.show()

# %% [markdown]
# ##  2.6. user.json

# %% [markdown]
# ### 2.6.1 Thống kê mô tả

# %%
len(user_df)
# Out:
# 3330294

# %%
user_df['gender'].describe()
# Out:
# count    3.330240e+06
# mean     9.455748e-01
# std      8.321099e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      2.000000e+00
# max      2.320000e+02
# Name: gender, dtype: float64

# %%
user_df['gender'].value_counts()
# Out:
# gender
# 0.0      1221931
# 1.0      1067858
# 2.0      1040449
# 232.0          1
# 3.0            1
# Name: count, dtype: int64

# %%
len(user_df["school"].unique())
# Out:
# 25849

# %%
user_df['school'].describe()
# Out:
# count                  1128399
# unique                   25848
# top        Tsinghua University
# freq                     18318
# Name: school, dtype: object

# %%
user_df['year_of_birth'].describe()
# Out:
# count    48530.000000
# mean      2039.016299
# std        358.674303
# min       1111.000000
# 25%       2020.000000
# 50%       2020.000000
# 75%       2020.000000
# max       9989.000000
# Name: year_of_birth, dtype: float64

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3330294 entries, 0 to 3330293
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   id             object
#  1   name           object
#  2   gender         float64
#  3   school         object
#  4   year_of_birth  float64
#  5   course_order   object
#  6   enroll_time    object
# dtypes: float64(2), object(5)
# memory usage: 177.9+ MB

# %%
total_users = user_df.shape[0]
print(f"1) Total number of users: {total_users}")

print('-----------------')

school_counts = user_df['school'].explode().value_counts()
print(f"2) Number of users by school:")
print(school_counts)
# Out:
# 1) Total number of users: 3330294
# -----------------
# 2) Number of users by school:
# school
#  Tsinghua University                                                       18318
#  Kunming University of Science and Technology                              15024
#  Hunan University                                                          13134
#  Henan University of Technology                                             9963
#  Hebei University of Technology                                             9635
#                                                                            ...
#  15188667353                                                                   1
#  School of Computer Science, South-Central University for Nationalities        1
# Dalian Neusoft Institute of Information                                        1
#  Neusoft School of Information and Business Management                         1
# ...

# %%
user_df['school_length'] = user_df['school'].apply(lambda x: len(x) if x is not None else 0)

user_df['school_length'].describe()
# Out:
# count    3.330294e+06
# mean     1.137576e+01
# std      1.756154e+01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.400000e+01
# max      1.740000e+02
# Name: school_length, dtype: float64

# %% [markdown]
# ### 2.6.2. Trực quan hóa dữ liệu

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot school_length, bins=10 để chia thành 10 khoảng, kde=True để vẽ đường KDE
plt.figure(figsize=(10, 6))
sns.histplot(user_df['school_length'], bins=10, kde=True)
plt.title('School Length')
plt.xlabel('Text Length')
plt.ylabel('Frequency')
plt.show()

# %%
# 'gender' Distribution 
plt.figure(figsize=(6, 4))
sns.countplot(x='gender', data=user_df)
plt.title('Gender Distribution')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # 3. Làm sạch dữ liệu

# %% [markdown]
# ## 3.1. course.json

# %% [markdown]
# ### Nhất quán cột `id` theo bảng `course-field.json`

# %%
course_df['id'] = course_df['id'].apply(lambda x: x.split('_')[1])
course_df['id'] = course_df['id'].astype(int)
course_df.rename(columns={'field': 'field_trans'}, inplace=True)
course_df.head()
# Out:
#        id                                         name_trans  \
# 0  584313                 introduction to "zi zhi tong jian"
# 1  584329  calculus - limit theory and functions of one v...
# 2  584381                                    photojournalism
# 3  597208                 data mining: theory and algorithms
# 4  597225                                university computer
#
#                                          field_trans prerequisites_trans  \
# 0         [history, chinese language and literature]
# 1  [applied economics, math, physics, theoretical...
# 2                [art, journalism and communication]
# 3                  [computer science and technology]
# 4                                                 []
#
#                                          about_trans  \
# 0  through the teacher's guidance, students can g...
# 1  this course is a basic mathematics course in s...
# 2  master basic photography skills, understand ho...
# ...

# %% [markdown]
# ### Kiểm tra: thiếu, lỗi, trùng lặp

# %%
def check_empty(df):
    empty_counts = df.apply(lambda x: ((x == "") | (x.apply(lambda y: y == [])) | (x.apply(lambda y: y == ()))).sum())
    return empty_counts

# %%
null_col = course_df.isnull().sum() #null
na_col = course_df.isna().sum()    #na
dup_col = pd.Series(course_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(course_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#                      NaN values  NA values  Duplicated rows  Empty values
# id                            0          0                0             0
# name_trans                    0          0              647             0
# field_trans                   0          0             3634          3234
# prerequisites_trans           0          0             3008          2580
# about_trans                   0          0              591            89
# resource                      0          0                0             0
# about_length                  0          0             2917             0
# name_length                   0          0             3653             0
# resource_length               0          0             3515             0
# field_count                   0          0             3774             0
# has_prerequisites             0          0             3779             0

# %%
course_df['field_trans'] = course_df['field_trans'].apply(tuple)
course_df['resource'] = course_df['resource'].apply(tuple)
print(f'Duplicated value overall: {course_df.iloc[:, 0:5].duplicated().sum()}')
# Out:
# Duplicated value overall: 0

# %% [markdown]
# *xét bảng `course_field.json`

# %%
course_field_df_name = 'course-field_translated.json'

course_field_df_2 = pd.read_json(os.path.join(path, course_field_df_name), lines=True)

# %%
course_field_df_2.head(5)
# Out:
#    course_id                                  course_name  \
# 0     584313           Introduction to "Zi Zhi Tong Jian"
# 1     681932         "Learning by doing" Java programming
# 2     674962   The spatial art of "Dream of Red Mansions"
# 3     682709  Introduction to the Critique of Pure Reason
# 4     682635               Introduction to "Tongwancheng"
#
#                                         field
# 0  [Chinese language and literature, History]
# 1           [Computer Science and Technology]
# 2           [Chinese language and literature]
# 3                                [philosophy]
# 4                                   [History]

# %%
course_field_df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   course_id    632 non-null    int64
#  1   course_name  632 non-null    object
#  2   field        632 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 14.9+ KB

# %%
course_1 = set(course_field_df_2['course_id'].unique())
course_2 = set(course_df['id'].unique())

# Courses that not exist 
courses_not_exists = course_1.difference(course_2)
num_courses_not_exists = len(courses_not_exists)

# Courses exist in both datasets
num_courses_in_both = len(course_1 & course_2)

print(f"Number of courses in course-field.json that do not exist in course.json: {num_courses_not_exists}")
print(f"Number of courses in course-field.json that exist in course.json: {num_courses_in_both}")
# Out:
# Number of courses in course-field.json that do not exist in course.json: 85
# Number of courses in course-field.json that exist in course.json: 547

# %% [markdown]
# ### dùng phép join 2 bảng lại với nhau

# %%
courses_list = course_df.iloc[:, :6].join(course_field_df_2.set_index('course_id'), on='id')
courses_list.head()
# Out:
#        id                                         name_trans  \
# 0  584313                 introduction to "zi zhi tong jian"
# 1  584329  calculus - limit theory and functions of one v...
# 2  584381                                    photojournalism
# 3  597208                 data mining: theory and algorithms
# 4  597225                                university computer
#
#                                          field_trans prerequisites_trans  \
# 0         (history, chinese language and literature)
# 1  (applied economics, math, physics, theoretical...
# 2                (art, journalism and communication)
# 3                 (computer science and technology,)
# 4                                                 ()
#
#                                          about_trans  \
# 0  through the teacher's guidance, students can g...
# 1  this course is a basic mathematics course in s...
# 2  master basic photography skills, understand ho...
# ...

# %%
null_col = courses_list.isnull().sum() #null
na_col = courses_list.isna().sum()    #na
dup_col = pd.Series(courses_list.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(courses_list) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#                      NaN values  NA values  Duplicated rows  Empty values
# id                            0          0                0             0
# name_trans                    0          0              647             0
# field_trans                   0          0             3634          3234
# prerequisites_trans           0          0             3008          2580
# about_trans                   0          0              591            89
# resource                      0          0                0             0
# course_name                3234       3234             3253             0
# field                      3234       3234             3624             0

# %% [markdown]
# kiểm tra kĩ về các dòng có cột name trùng lặp

# %%
dup_name = courses_list[courses_list.apply(lambda x: x.duplicated())["name_trans"]]
dup_name.head()
# Out:
#         id                              name_trans field_trans  \
# 14  629514      introduction to "zi zhi tong jian"          ()
# 47  674966   the analects of confucius life lesson          ()
# 50  676637  financial analysis and decision-making          ()
# 52  676641                     university computer          ()
# 66  676665   the rise and fall of the tang dynasty          ()
#
#    prerequisites_trans                                        about_trans  \
# 14                      through the teacher's guidance, students can g...
# 47                      "the analects of confucius" is a collection of...
# 50                      this course uses financial language to deconst...
# 52                      university computer courses will be guided by ...
# 66                      the history of the sui, tang and five dynastie...
#
#                                              resource course_name field
# ...

# %%
res = dup_name[dup_name['name_trans'] == "introduction to the basic principles of marxism"]
res
# Out:
#            id                                       name_trans  \
# 1490   769273  introduction to the basic principles of marxism
# 1598   837985  introduction to the basic principles of marxism
# 2826  1891061  introduction to the basic principles of marxism
# 3757  2342515  introduction to the basic principles of marxism
#
#                field_trans                                prerequisites_trans  \
# 1490  (political science,)
# 1598                    ()  "ideological and moral cultivation and legal b...
# 2826                    ()
# 3757                    ()  ideological and moral cultivation and legal fo...
#
#                                             about_trans  \
# 1490  "basic principles of marxism" educates college...
# 1598  why is marx right? what are “universal values”...
# 2826  the basic principles of marxism are the basic ...
# 3757  the course "introduction to the basic principl...
#
#                                                resource  \
# ...

# %%
from scipy.stats import chi2_contingency

# dup_name['field'] = dup_name['field'].apply(str)
# dup_name = dup_name.iloc[:, :6]
contingency_table = pd.crosstab(dup_name['name_trans'], dup_name['about_trans'])

# Perform the Chi-Square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Display the results
print("Chi-Square Test Results")
print(f"P-Value: {p}")
# Out:
# Chi-Square Test Results
# P-Value: 4.270000750126942e-107

# %% [markdown]
# > Ta kết luận **tồn tại** sự trùng lặp giữa các dòng này mặc dù khác `id` nhưng giống nhau về mặt nội dung, ta tiến hành xoá các dòng trùng lặp

# %%
## only drop the rows that have the same name and field
course_df.drop_duplicates(subset=['name_trans', 'field_trans'], keep='first', inplace=True)

# %%
course_df[course_df['name_trans'] == "introduction to the basic principles of marxism"]
# Out:
#           id                                       name_trans  \
# 1243  707079  introduction to the basic principles of marxism
# 1598  837985  introduction to the basic principles of marxism
#
#                field_trans                                prerequisites_trans  \
# 1243  (political science,)
# 1598                    ()  "ideological and moral cultivation and legal b...
#
#                                             about_trans  \
# 1243  a basic introduction to marxism course, which ...
# 1598  why is marx right? what are “universal values”...
#
#                                                resource  about_length  \
# 1243  ({'titles': ['绪论 深刻影响和改变世界历史的科学理论', '一.什么是马克思主...            99
# 1598  ({'titles': ['专题一：为什么是马克思？', '1.1 为什么是马克思主义？',...           199
#
#       name_length  resource_length  field_count  has_prerequisites
# 1243           47               92            1              False
# 1598           47               62            0               True

# %% [markdown]
# ## 3.2. concept.json

# %% [markdown]
# ### xử lý dữ liệu thiếu

# %%
print("Số lượng giá trị thiếu trong từng cột:")
print(concept_df.isnull().sum())
# Out:
# Số lượng giá trị thiếu trong từng cột:
# id         0
# name       0
# context    0
# dtype: int64

# %% [markdown]
# ### xử lý dữ liệu trùng lặp

# %%
print("Số lượng bản ghi trùng lặp:", concept_df.duplicated().sum())
concept_df = concept_df.drop_duplicates()
print("Số lượng trùng lặp sau khi xử lý:", concept_df.duplicated().sum())
# Out:
# Số lượng bản ghi trùng lặp: 0
# Số lượng trùng lặp sau khi xử lý: 0

# %% [markdown]
# ## 3.3. course-field.json

# %% [markdown]
# ### 3.3.1. Xử lý dữ liệu thiếu

# %%
# Kiểm tra dữ liệu thiếu
print("Số lượng giá trị thiếu trong từng cột:")
print(course_field_df.isnull().sum())

# Tỷ lệ dữ liệu thiếu
missing_ratio = course_field_df.isnull().mean() * 100
print("\nTỷ lệ dữ liệu thiếu trong từng cột (%):")
print(missing_ratio)

# Xử lý dữ liệu thiếu
# 1. Loại bỏ các hàng chứa giá trị thiếu
df_dropped = course_field_df.dropna()

# Kiểm tra lại số lượng giá trị thiếu sau khi xử lý
print("\nSố lượng giá trị thiếu sau khi xử lý:")
print(df_dropped.isnull().sum())  # Nếu dùng phương pháp loại bỏ
# print(df.isnull().sum())  # Nếu dùng phương pháp thay thế
# Out:
# Số lượng giá trị thiếu trong từng cột:
# course_id      0
# course_name    0
# field          0
# dtype: int64
#
# Tỷ lệ dữ liệu thiếu trong từng cột (%):
# course_id      0.0
# course_name    0.0
# field          0.0
# dtype: float64
#
# Số lượng giá trị thiếu sau khi xử lý:
# course_id      0
# course_name    0
# field          0
# dtype: int64

# %% [markdown]
# ### 3.3.2. Xử lý dữ liệu nhiễu

# %%
import re
# Hàm loại bỏ ký tự không mong muốn
def clean_text(text):
    # Loại bỏ ký tự đặc biệt
    text = re.sub(r'[^\w\s]', '', text)  # Giữ lại chữ cái, số và khoảng trắng
    text = text.strip()  # Loại bỏ khoảng trắng thừa ở hai đầu
    text = text.lower()  # Chuyển về viết thường
    return text


# Tiến hành xử lý cho cột 'course_name'
course_field_df['cleaned_course_name'] = course_field_df['course_name'].apply(clean_text)

# Kiểm tra dữ liệu đã xử lý
course_field_df[['course_id', 'course_name', 'cleaned_course_name']].head()
# Out:
#    course_id                                  course_name  \
# 0     584313           Introduction to "Zi Zhi Tong Jian"
# 1     681932         "Learning by doing" Java programming
# 2     674962   The spatial art of "Dream of Red Mansions"
# 3     682709  Introduction to the Critique of Pure Reason
# 4     682635               Introduction to "Tongwancheng"
#
#                            cleaned_course_name
# 0             introduction to zi zhi tong jian
# 1           learning by doing java programming
# 2     the spatial art of dream of red mansions
# 3  introduction to the critique of pure reason
# 4                 introduction to tongwancheng

# %% [markdown]
# ### 3.3.3. Xử lý dữ liệu trùng lặp

# %%
# Chuyển đổi cột 'field' thành chuỗi
course_field_df['field'] = course_field_df['field'].apply(lambda x: ', '.join(x))

# Kiểm tra dữ liệu trùng lặp
duplicate_rows = course_field_df.duplicated()

# Đếm số lượng bản ghi trùng lặp
num_duplicates = duplicate_rows.sum()
print(f"Số lượng bản ghi trùng lặp: {num_duplicates}")

# Hiển thị các bản ghi trùng lặp
if num_duplicates > 0:
    print("Các bản ghi trùng lặp:")
    print(course_field_df[duplicate_rows])

# Xóa bản ghi trùng lặp (nếu cần)
df_cleaned = course_field_df.drop_duplicates()

# Kiểm tra lại số lượng bản ghi sau khi xóa trùng lặp
print(f"Số lượng bản ghi sau khi xóa trùng lặp: {len(df_cleaned)}")
# Out:
# Số lượng bản ghi trùng lặp: 0
# Số lượng bản ghi sau khi xóa trùng lặp: 632

# %% [markdown]
# ## 3.4. school.json

# %% [markdown]
# ### Kiểm tra thiếu, nhiễu, không nhất quán, trùng lặp

# %%
def check_empty(school_df):
    empty_string_counts = school_df.apply(lambda x: (x == "").sum())
    return empty_string_counts

# %%
null_col = school_df.isnull().sum() #null
na_col = school_df.isna().sum()    #na
dup_col = pd.Series(school_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(school_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#               NaN values  NA values  Duplicated rows  Empty values
# id                     0          0                0             0
# name                   0          0                7             0
# name_en                0          0                5             0
# sign                   0          0                8             0
# about                  0          0                8             0
# motto                  0          0              290           282
# about_length           0          0               48             0
# motto_length           0          0              368             0

# %%
print(f'Duplicated value overall: {school_df.duplicated().sum()}')
# Out:
# Duplicated value overall: 0

# %%
unique_name_en = school_df['name_en'].nunique() == len(school_df)
non_empty_name_en = school_df['name_en'].apply(lambda x: bool(x.strip())).all()

print(f"'name_en' is unique: {unique_name_en}")
print(f"'name_en' is non-empty: {non_empty_name_en}")
# Out:
# 'name_en' is unique: False
# 'name_en' is non-empty: True

# %%
name_en_counts = school_df['name_en'].value_counts()
name_en_counts[ name_en_counts > 1 ]
# Out:
# name_en
# Dalian University of Technology                    2
# Chang’an University                                2
# Guizhou Institute of Technology                    2
# Hebei Normal University of Science & Technology    2
# Chinese Academy of Sciences                        2
# Name: count, dtype: int64

# %%
id_check = school_df['id'].str.startswith("S_").all()
print(f"ID format is correct: {id_check}")
# Out:
# ID format is correct: True

# %% [markdown]
# ### xử lý dữ liệu không nhất quán

# %%
### drop Chinese name bc we name English name columns
school_df.drop(columns=['name'], inplace=True)
school_df.head()
# Out:
#     id              name_en  sign  \
# 0  S_1  Tsinghua University   thu
# 1  S_2    Peking University   PKU
# 2  S_3     Wuhan University   whu
# 3  S_4   Soochow University  suda
# 4  S_5   Sichuan University   scu
#
#                                                about  \
# 0  "Tsinghua" for short, is directly under the Mi...
# 1  Peking University, referred to as "Peking Univ...
# 2  Wuhan University (Wuhan University), referred ...
# 3  Soochow University, located in the historical ...
# 4  Sichuan University, referred to as "Sichuan Un...
#
#                                                motto  about_length  \
# 0  Constantly strive for self-improvement and be ...           802
# 1  erudition, inquiry, careful consideration, dis...          2685
# 2  Self-improvement, Hongyi, Seeking truth, Expan...          2587
# 3  Nourish the righteousness of heaven and earth,...          2629
# 4                                                             2949
#
#    motto_length
# ...

# %%
school_df['sign'] = school_df['sign'].str.upper() ## convert to uppercase for consistent
school_df['sign'].value_counts()
# Out:
# sign
# HZIC        2
# XJTU        2
# GIT         2
# HEBEI       2
# QDU         2
#            ..
# GDUT        1
# PASTEURX    1
# DELFTX      1
# RICE        1
# HLJUCM      1
# Name: count, Length: 419, dtype: int64

# %% [markdown]
# ### Xử lí dữ liệu trùng lặp

# %%
school_df.drop_duplicates(subset=['name_en'], keep='first', inplace=True)
school_df.drop_duplicates(subset=['sign'], keep='first', inplace=True)

# %%
name_en_counts = school_df['name_en'].value_counts()
name_en_counts[ name_en_counts > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
sign_counts = school_df['sign'].value_counts()
sign_counts[ sign_counts > 1]
# Out:
# Series([], Name: count, dtype: int64)

# %%
school_df.head()
# Out:
#     id              name_en  sign  \
# 0  S_1  Tsinghua University   THU
# 1  S_2    Peking University   PKU
# 2  S_3     Wuhan University   WHU
# 3  S_4   Soochow University  SUDA
# 4  S_5   Sichuan University   SCU
#
#                                                about  \
# 0  "Tsinghua" for short, is directly under the Mi...
# 1  Peking University, referred to as "Peking Univ...
# 2  Wuhan University (Wuhan University), referred ...
# 3  Soochow University, located in the historical ...
# 4  Sichuan University, referred to as "Sichuan Un...
#
#                                                motto  about_length  \
# 0  Constantly strive for self-improvement and be ...           802
# 1  erudition, inquiry, careful consideration, dis...          2685
# 2  Self-improvement, Hongyi, Seeking truth, Expan...          2587
# 3  Nourish the righteousness of heaven and earth,...          2629
# 4                                                             2949
#
#    motto_length
# ...

# %% [markdown]
# ## 3.5. teacher.json

# %% [markdown]
# ## 3.6. user.json

# %% [markdown]
# ### 3.6.1 Xử lý dữ liệu thiếu

# %%
# Loại bỏ cột 'year_of_birth' cùng các dòng bị thiếu dữ liệu
user_df = user_df.drop(columns=['year_of_birth'])
user_df = user_df.dropna()

# %% [markdown]
# ### 3.6.2. Xử lý dữ liệu nhiễu

# %%
# Loại bỏ dữ liệu nhiễu
user_df['gender'] = user_df['gender'].replace({232.0: None, 3.0: None})
user_df.dropna(subset=['gender'], inplace=True)

# %% [markdown]
# ### 3.6.3. Xử lý dữ liệu trùng lặp

# %%
# Kiểm tra:

len(user_df['id'].unique()) / len(user_df)
# Out:
# 1.0

# %%
user_df.head()
# Out:
#      id name  gender                school  \
# 1  U_24  王帅国     1.0   Tsinghua University
# 2  U_25  王帅国     0.0   Tsinghua University
# 3  U_53  于歆杰     1.0   Tsinghua University
# 4  U_54  马昱春     2.0   Tsinghua University
# 5  U_67  李小马     1.0         School Online
#
#                                         course_order  \
# 1  [597214, 605512, 597211, 597314, 597208, 62950...
# 2                                          [1903985]
# 3  [696679, 1704639, 943255, 1729417, 682164, 177...
# 4  [682442, 682164, 1748240, 1778890, 1829031, 17...
# 5                                           [696679]
#
#                                          enroll_time  school_length
# 1  [2019-05-20 16:06:48, 2019-05-24 19:34:43, 201...             20
# 2                              [2020-08-07 18:59:13]             20
# 3  [2020-03-01 21:24:30, 2020-03-12 16:17:02, 202...             20
# 4  [2019-10-09 02:17:49, 2019-11-08 00:49:03, 202...             20
# ...

# %% [markdown]
# # 4. Kiểm tra dữ liệu sau cùng

# %% [markdown]
# ## 4.1. course.json

# %%
course_df.head()
# Out:
#        id                                         name_trans  \
# 0  584313                 introduction to "zi zhi tong jian"
# 1  584329  calculus - limit theory and functions of one v...
# 2  584381                                    photojournalism
# 3  597208                 data mining: theory and algorithms
# 4  597225                                university computer
#
#                                          field_trans prerequisites_trans  \
# 0         (history, chinese language and literature)
# 1  (applied economics, math, physics, theoretical...
# 2                (art, journalism and communication)
# 3                 (computer science and technology,)
# 4                                                 ()
#
#                                          about_trans  \
# 0  through the teacher's guidance, students can g...
# 1  this course is a basic mathematics course in s...
# 2  master basic photography skills, understand ho...
# ...

# %%
course_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3278 entries, 0 to 3780
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   3278 non-null   int32
#  1   name_trans           3278 non-null   object
#  2   field_trans          3278 non-null   object
#  3   prerequisites_trans  3278 non-null   object
#  4   about_trans          3278 non-null   object
#  5   resource             3278 non-null   object
#  6   about_length         3278 non-null   int64
#  7   name_length          3278 non-null   int64
#  8   resource_length      3278 non-null   int64
#  9   field_count          3278 non-null   int64
#  10  has_prerequisites    3278 non-null   bool
# dtypes: bool(1), int32(1), int64(4), object(5)
# memory usage: 272.1+ KB

# %%
null_col = course_df.isnull().sum() #null
na_col = course_df.isna().sum()    #na
dup_col = pd.Series(course_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(course_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#                      NaN values  NA values  Duplicated rows  Empty values
# id                            0          0                0             0
# name_trans                    0          0              144             0
# field_trans                   0          0             3131             0
# prerequisites_trans           0          0             2635          2269
# about_trans                   0          0              410            78
# resource                      0          0                0             0
# about_length                  0          0             2446             0
# name_length                   0          0             3150             0
# resource_length               0          0             3024             0
# field_count                   0          0             3271             0
# has_prerequisites             0          0             3276             0

# %% [markdown]
# ## 4.2. concept.json

# %%
concept_df.head()
# Out:
#                    id                  name  \
# 0       K_神经部_组织学与胚胎学        Nervous system
# 1  K_促甲状腺激素细胞_组织学与胚胎学             TSH cells
# 2      K_嗜色细胞_组织学与胚胎学    Chromophilic cells
# 3    K_生长激素细胞_组织学与胚胎学  Growth hormone cells
# 4       K_褐铁矿_材料科学与工程              Limonite
#
#                                              context
# 0                                                 []
# 1  ['The pituitary gland consists of two parts: t...
# 2                                                 []
# 3  ['Answer: B\n13. Adenohypophysis eosinophils c...
# 4  ['\nLimonite is a common iron ore, often forme...

# %%
concept_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637572 entries, 0 to 637571
# Data columns (total 3 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       637572 non-null  object
#  1   name     637572 non-null  object
#  2   context  637572 non-null  object
# dtypes: object(3)
# memory usage: 14.6+ MB

# %%
null_col = concept_df.isnull().sum() #null
na_col = concept_df.isna().sum()    #na
dup_col = pd.Series(concept_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(concept_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#          NaN values  NA values  Duplicated rows  Empty values
# id                0          0                0             0
# name              0          0           147686             0
# context           0          0           536006             0

# %% [markdown]
# ## 4.3. course-field.json

# %%
course_field_df.head()
# Out:
#    course_id                                  course_name  \
# 0     584313           Introduction to "Zi Zhi Tong Jian"
# 1     681932         "Learning by doing" Java programming
# 2     674962   The spatial art of "Dream of Red Mansions"
# 3     682709  Introduction to the Critique of Pure Reason
# 4     682635               Introduction to "Tongwancheng"
#
#                                       field  \
# 0  Chinese language and literature, History
# 1           Computer Science and Technology
# 2           Chinese language and literature
# 3                                philosophy
# 4                                   History
#
#                            cleaned_course_name
# 0             introduction to zi zhi tong jian
# 1           learning by doing java programming
# 2     the spatial art of dream of red mansions
# 3  introduction to the critique of pure reason
# 4                 introduction to tongwancheng

# %%
course_field_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 632 entries, 0 to 631
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            632 non-null    int64
#  1   course_name          632 non-null    object
#  2   field                632 non-null    object
#  3   cleaned_course_name  632 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 19.9+ KB

# %%
null_col = course_field_df.isnull().sum() #null
na_col = course_field_df.isna().sum()    #na
dup_col = pd.Series(course_field_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(course_field_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#                      NaN values  NA values  Duplicated rows  Empty values
# course_id                     0          0                0             0
# course_name                   0          0               23             0
# field                         0          0              460             0
# cleaned_course_name           0          0               23             0

# %% [markdown]
# ## 4.4. school.json

# %%
school_df.head()
# Out:
#     id              name_en  sign  \
# 0  S_1  Tsinghua University   THU
# 1  S_2    Peking University   PKU
# 2  S_3     Wuhan University   WHU
# 3  S_4   Soochow University  SUDA
# 4  S_5   Sichuan University   SCU
#
#                                                about  \
# 0  "Tsinghua" for short, is directly under the Mi...
# 1  Peking University, referred to as "Peking Univ...
# 2  Wuhan University (Wuhan University), referred ...
# 3  Soochow University, located in the historical ...
# 4  Sichuan University, referred to as "Sichuan Un...
#
#                                                motto  about_length  \
# 0  Constantly strive for self-improvement and be ...           802
# 1  erudition, inquiry, careful consideration, dis...          2685
# 2  Self-improvement, Hongyi, Seeking truth, Expan...          2587
# 3  Nourish the righteousness of heaven and earth,...          2629
# 4                                                             2949
#
#    motto_length
# ...

# %%
school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 418 entries, 0 to 427
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            418 non-null    object
#  1   name_en       418 non-null    object
#  2   sign          418 non-null    object
#  3   about         418 non-null    object
#  4   motto         418 non-null    object
#  5   about_length  418 non-null    int64
#  6   motto_length  418 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 26.1+ KB

# %%
null_col = school_df.isnull().sum() #null
na_col = school_df.isna().sum()    #na
dup_col = pd.Series(school_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(school_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#               NaN values  NA values  Duplicated rows  Empty values
# id                     0          0                0             0
# name_en                0          0                0             0
# sign                   0          0                0             0
# about                  0          0                2             0
# motto                  0          0              282           276
# about_length           0          0               42             0
# motto_length           0          0              358             0

# %% [markdown]
# ## 4.5. teacher.json

# %%
teacher_df.head()
# Out:
#     id name        name_en                                              about  \
# 0  T_1  刘燕妮      Yanni Liu  Graduated from the Philosophy Department of Pe...
# 1  T_2   陈怡        Yi Chen  Born in Chongqing in 1945, he graduated from H...
# 2  T_3   程钢     Gang Cheng  Cheng Gang is the course leader of "Introducti...
# 3  T_4  谢维和     xie wei he  Xie Weihe, PhD, professor, doctoral supervisor...
# 4  T_5  史静寰  Jing-huan Shi  Shi Jinghuan, female, professor and doctoral s...
#
#              job_title             org_name
# 0             lecturer  Tsinghua University
# 1            professor  Tsinghua University
# 2  Associate Professor  Tsinghua University
# 3            professor  Tsinghua University
# 4            professor  Tsinghua University

# %%
teacher_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17018 entries, 0 to 17017
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         17018 non-null  object
#  1   name       17018 non-null  object
#  2   name_en    17018 non-null  object
#  3   about      13893 non-null  object
#  4   job_title  14768 non-null  object
#  5   org_name   17018 non-null  object
# dtypes: object(6)
# memory usage: 797.8+ KB

# %%
null_col = teacher_df.isnull().sum() #null
na_col = teacher_df.isna().sum()    #na
dup_col = pd.Series(teacher_df.apply(lambda x: x.duplicated().sum())) #dup
empty_col = check_empty(teacher_df) #empty

result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
result
# Out:
#            NaN values  NA values  Duplicated rows  Empty values
# id                  0          0                0             0
# name                0          0             3051             0
# name_en             0          0             5957          4142
# about            3125       3125             4481             0
# job_title        2250       2250            15694             0
# org_name            0          0            16020             0

# %% [markdown]
# ## 4.6. user.json

# %%
user_df.head()
# Out:
#      id name  gender                school  \
# 1  U_24  王帅国     1.0   Tsinghua University
# 2  U_25  王帅国     0.0   Tsinghua University
# 3  U_53  于歆杰     1.0   Tsinghua University
# 4  U_54  马昱春     2.0   Tsinghua University
# 5  U_67  李小马     1.0         School Online
#
#                                         course_order  \
# 1  [597214, 605512, 597211, 597314, 597208, 62950...
# 2                                          [1903985]
# 3  [696679, 1704639, 943255, 1729417, 682164, 177...
# 4  [682442, 682164, 1748240, 1778890, 1829031, 17...
# 5                                           [696679]
#
#                                          enroll_time  school_length
# 1  [2019-05-20 16:06:48, 2019-05-24 19:34:43, 201...             20
# 2                              [2020-08-07 18:59:13]             20
# 3  [2020-03-01 21:24:30, 2020-03-12 16:17:02, 202...             20
# 4  [2019-10-09 02:17:49, 2019-11-08 00:49:03, 202...             20
# ...

# %%
user_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1128390 entries, 1 to 3329907
# Data columns (total 7 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   id             1128390 non-null  object
#  1   name           1128390 non-null  object
#  2   gender         1128390 non-null  float64
#  3   school         1128390 non-null  object
#  4   course_order   1128390 non-null  object
#  5   enroll_time    1128390 non-null  object
#  6   school_length  1128390 non-null  int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 68.9+ MB

# %%
# null_col = user_df.isnull().sum() #null
# na_col = user_df.isna().sum()    #na
# dup_col = pd.Series(user_df.apply(lambda x: x.duplicated().sum())) #dup
# empty_col = check_empty(user_df) #empty

# result = pd.concat([null_col, na_col, dup_col, empty_col], axis=1)
# result.columns = ['NaN values', 'NA values', 'Duplicated rows', "Empty values"]
# result
