# %% [markdown]
# # Load data nam ngoai

# %%
# !pip install gitpython

# %%
# import git
# git.Repo.clone_from('https://github.com/SonRobo/knowledge_graph_attention_network.git', '/kaggle/working/new_kgat')

# %%
# # Path to the existing repo
# repo_dir = '/kaggle/working/new_kgat'

# # Open the existing repository
# repo = git.Repo(repo_dir)

# # Pull the latest changes from the repository
# repo.remotes.origin.pull()

# %%
# !python /kaggle/working/pytorch_kgat/main_kgat.py --data_name amazon-book

# %%
# !pip install gitpython
import git
git.Repo.clone_from('https://github.com/dnsang1611/CS313-CourseRecommendation-Code.git', '/kaggle/working/sample')
# Out:
# ...
# <git.repo.base.Repo '/kaggle/working/sample/.git'>

# %%
# # Path to the existing repo
# repo_dir = '/kaggle/working/sample'

# # Open the existing repository
# repo = git.Repo(repo_dir)

# # Pull the latest changes from the repository
# repo.remotes.origin.pull()

# %%
# !python /kaggle/working/sample/KGAT-pytorch/main_kgat.py \
                    --seed 42 \
                    --data_dir "/kaggle/input/mooccubex-ds317" \
                    --data_name features_preprocessed \
                    --use_pretrain 0 \
                    --n_epoch 100 \
                    --cf_batch_size 1024 \
                    --kg_batch_size 2048 \
                    --test_batch_size 256 \
                    --cf_print_every 500 \
                    --kg_print_every 500 \
                    --stopping_steps 5 \
                    --evaluate_every 5 \
                    --Ks '[1, 5, 10]'
# Out:
# All logs will be saved to trained_model/KGAT/features_preprocessed/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/log0.log
# 2024-12-07 13:33:29,872 - root - INFO - Namespace(seed=42, data_name='features_preprocessed', data_dir='/kaggle/input/mooccubex-ds317', use_pretrain=0, pretrain_embedding_dir='datasets/pretrain/', pretrain_model_path='trained_model/model.pth', cf_batch_size=1024, kg_batch_size=2048, test_batch_size=256, embed_dim=64, relation_dim=64, laplacian_type='random-walk', aggregation_type='bi-interaction', conv_dim_list='[64, 32, 16]', mess_dropout='[0.1, 0.1, 0.1]', kg_l2loss_lambda=1e-05, cf_l2loss_lambda=1e-05, lr=0.0001, n_epoch=100, stopping_steps=5, cf_print_every=500, kg_print_every=500, evaluate_every=5, Ks='[1, 5, 10]', save_dir='trained_model/KGAT/features_preprocessed/embed-dim64_relation-dim64_random-walk_bi-interaction_64-32-16_lr0.0001_pretrain0/')
# 2024-12-07 13:34:37,844 - root - INFO - n_users:           97722
# ...

# %%
# !python /kaggle/working/sample/KGAT-pytorch/predict_kgat.py \
#                     --data_dir "/kaggle/input/mooc-data-set/model data contain real test/model data contain real test/Model Data" \
#                     --data_name "" \
#                     --use_pretrain 2 \
#                     --pretrain_model_path /kaggle/input/test-model/model_epoch1.pth \
#                     --n_epoch 6 \
#                     --cf_batch_size 1024 \
#                     --kg_batch_size 2048 \
#                     --test_batch_size 256 \
#                     --cf_print_every 500 \
#                     --kg_print_every 50 \
#                     --evaluate_every 2 \
#                     --Ks '[1, 5, 10]'

# %% [markdown]
# # Run NFM

# %%
# !pip install gitpython
# import git
# git.Repo.clone_from('https://github.com/dnsang1611/CS313-CourseRecommendation-Code.git', '/kaggle/working/sample')

# %%
# !python /kaggle/working/sample/KGAT-pytorch/main_nfm.py \
#                     --data_dir "/kaggle/input/mooc-data-test/Model Data" \
#                     --model_type nfm \
#                     --data_name "" \
#                     --n_epoch 1 \
#                     --use_pretrain 0 \
#                     --use_user_info 1\
#                     --train_batch_size 1024 \
#                     --test_batch_size 1024 \
#                     --test_cores 0 \
#                     --print_every 50 \
#                     --evaluate_every 5 \
#                     --Ks '[1, 5, 10]'
